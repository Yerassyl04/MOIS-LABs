# %%
# !pip install ydf -U
# Out:
# Collecting ydf
#   Obtaining dependency information for ydf from https://files.pythonhosted.org/packages/e8/7d/e6024a58a07dc059034e2ba5f6dc238cb72fbc1a39b2498c1fc8c73d6ff6/ydf-0.8.0-cp311-cp311-win_amd64.whl.metadata
#   Downloading ydf-0.8.0-cp311-cp311-win_amd64.whl.metadata (3.3 kB)
# Requirement already satisfied: numpy in c:\users\asus\anaconda3\lib\site-packages (from ydf) (1.24.3)
# Collecting absl-py (from ydf)
#   Obtaining dependency information for absl-py from https://files.pythonhosted.org/packages/a2/ad/e0d3c824784ff121c03cc031f944bc7e139a8f1870ffd2845cc2dd76f6c4/absl_py-2.1.0-py3-none-any.whl.metadata
#   Downloading absl_py-2.1.0-py3-none-any.whl.metadata (2.3 kB)
# Collecting protobuf>=3.14 (from ydf)
#   Obtaining dependency information for protobuf>=3.14 from https://files.pythonhosted.org/packages/9c/4c/4563ebe001ff30dca9d7ed12e471fa098d9759712980cde1fd03a3a44fb7/protobuf-5.28.3-cp310-abi3-win_amd64.whl.metadata
#   Downloading protobuf-5.28.3-cp310-abi3-win_amd64.whl.metadata (592 bytes)
# Downloading ydf-0.8.0-cp311-cp311-win_amd64.whl (5.3 MB)
#    ---------------------------------------- 0.0/5.3 MB ? eta -:--:--
#    ---------------------------------------- 0.0/5.3 MB ? eta -:--:--
#    ---------------------------------------- 0.0/5.3 MB 435.7 kB/s eta 0:00:12
#    ---------------------------------------- 0.0/5.3 MB 435.7 kB/s eta 0:00:12
#    ---------------------------------------- 0.1/5.3 MB 326.1 kB/s eta 0:00:16
#     --------------------------------------- 0.1/5.3 MB 502.0 kB/s eta 0:00:11
#     --------------------------------------- 0.1/5.3 MB 502.0 kB/s eta 0:00:11
#    - -------------------------------------- 0.2/5.3 MB 588.9 kB/s eta 0:00:09
#    - -------------------------------------- 0.3/5.3 MB 682.7 kB/s eta 0:00:08
#    -- ------------------------------------- 0.3/5.3 MB 729.6 kB/s eta 0:00:07
#    --- ------------------------------------ 0.5/5.3 MB 969.9 kB/s eta 0:00:05
#    --- ------------------------------------ 0.5/5.3 MB 982.5 kB/s eta 0:00:05
#    ---- ----------------------------------- 0.6/5.3 MB 1.1 MB/s eta 0:00:05
#    ------ --------------------------------- 0.9/5.3 MB 1.5 MB/s eta 0:00:03
#    ------- -------------------------------- 1.0/5.3 MB 1.6 MB/s eta 0:00:03
#    -------- ------------------------------- 1.1/5.3 MB 1.6 MB/s eta 0:00:03
#    ---------- ----------------------------- 1.4/5.3 MB 1.9 MB/s eta 0:00:03
#    -------------- ------------------------- 1.8/5.3 MB 2.3 MB/s eta 0:00:02
#    --------------- ------------------------ 2.1/5.3 MB 2.6 MB/s eta 0:00:02
#    ----------------- ---------------------- 2.4/5.3 MB 2.7 MB/s eta 0:00:02
#    --------------------- ------------------ 2.9/5.3 MB 3.1 MB/s eta 0:00:01
#    ----------------------- ---------------- 3.1/5.3 MB 3.3 MB/s eta 0:00:01
#    ----------------------- ---------------- 3.1/5.3 MB 3.3 MB/s eta 0:00:01
#    ----------------------- ---------------- 3.1/5.3 MB 3.3 MB/s eta 0:00:01
#    ----------------------- ---------------- 3.1/5.3 MB 3.3 MB/s eta 0:00:01
#    --------------------------- ------------ 3.6/5.3 MB 3.1 MB/s eta 0:00:01
#    ------------------------------- -------- 4.1/5.3 MB 3.4 MB/s eta 0:00:01
#    --------------------------------- ------ 4.4/5.3 MB 3.5 MB/s eta 0:00:01
#    ----------------------------------- ---- 4.6/5.3 MB 3.6 MB/s eta 0:00:01
#    ------------------------------------- -- 4.9/5.3 MB 3.6 MB/s eta 0:00:01
#    ---------------------------------------  5.2/5.3 MB 3.7 MB/s eta 0:00:01
#    ---------------------------------------  5.3/5.3 MB 3.7 MB/s eta 0:00:01
#    ---------------------------------------- 5.3/5.3 MB 3.6 MB/s eta 0:00:00
# Downloading protobuf-5.28.3-cp310-abi3-win_amd64.whl (431 kB)
#    ---------------------------------------- 0.0/431.5 kB ? eta -:--:--
#    --------------------------------------  430.1/431.5 kB 13.1 MB/s eta 0:00:01
#    ---------------------------------------- 431.5/431.5 kB 9.0 MB/s eta 0:00:00
# Downloading absl_py-2.1.0-py3-none-any.whl (133 kB)
#    ---------------------------------------- 0.0/133.7 kB ? eta -:--:--
#    ---------------------------------------- 133.7/133.7 kB 7.7 MB/s eta 0:00:00
# Installing collected packages: protobuf, absl-py, ydf
# Successfully installed absl-py-2.1.0 protobuf-5.28.3 ydf-0.8.0

# %%
import pandas as pd
import numpy as np
import ydf

path = "https://storage.googleapis.com/download.tensorflow.org/data/palmer_penguins/penguins.csv"
dataset = pd.read_csv(path)
label = "species"

dataset.head()
# Out:
#   species     island  bill_length_mm  bill_depth_mm  flipper_length_mm  \
# 0  Adelie  Torgersen            39.1           18.7              181.0
# 1  Adelie  Torgersen            39.5           17.4              186.0
# 2  Adelie  Torgersen            40.3           18.0              195.0
# 3  Adelie  Torgersen             NaN            NaN                NaN
# 4  Adelie  Torgersen            36.7           19.3              193.0
#
#    body_mass_g     sex  year
# 0       3750.0    male  2007
# 1       3800.0  female  2007
# 2       3250.0  female  2007
# 3          NaN     NaN  2007
# 4       3450.0  female  2007

# %%
np.random.seed(1)
is_test = np.random.rand(len(dataset)) < 0.2
train_dataset = dataset[~is_test]
test_dataset = dataset[is_test]

model = ydf.CartLearner(label=label).train(train_dataset)
model.plot_tree()

train_evaluation = model.evaluate(train_dataset)
print("Train accuracy:", train_evaluation.accuracy)

test_evaluation = model.evaluate(test_dataset)
print("Test accuracy:", test_evaluation.accuracy)
# Out:
# Train model on 272 examples
# Model trained in 0:00:00.004146
# Train accuracy: 0.9558823529411765
# Test accuracy: 0.9166666666666666
